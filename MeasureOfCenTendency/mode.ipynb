# %% [markdown]
# # Mode

# %% [markdown]
# *it shows most frequent value*

# %% [markdown]
# *1. using statistic multimode*

# %%
import statistics
l=[60,20,60,20,50,60,20]
print("multi mode :",statistics.multimode(l))
# Out:
# multi mode : [60, 20]

# %% [markdown]
# *2. using statistics*

# %%
import statistics
l=[60,20,60,40,50,60]
print("mode :",statistics.mode(l))
# Out:
# mode : 60

# %% [markdown]
# *3.using DATA SET*

# %%
import seaborn as sns
import statistics as np
d=sns.load_dataset("iris")
print(d)
m=np.multimode(d['sepal_length'])
print("MODE : ",m)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
# MODE :  [5.0]
