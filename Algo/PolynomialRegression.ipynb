# %% [markdown]
# ### Polynomial Regression

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt

# %%
x=6*np.random.rand(200,1)-3
y=0.8+x**2+0.9*x+2+np.random.randn(200,1)

# %%
plt.plot(x,y,'b.')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.3131504655256324

# %%
plt.plot(x_train,lr.predict(x_train),color="red")
plt.plot(x,y,'b.')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# ### Apply polynomial linear reg

# %%
## with degree 2
poly=PolynomialFeatures(degree=2)
x_train_trans=poly.fit_transform(x_train)
x_test_trans=poly.fit_transform(x_test)

# %%
print("input",poly.n_input_features_)
print("output",poly.n_output_features_)
print("degree",poly.degree)
print("powers",poly.powers_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 print("input",poly.n_input_features_)
#       2 print("output",poly.n_output_features_)
#       3 print("degree",poly.degree)
#
# AttributeError: 'PolynomialFeatures' object has no attribute 'n_input_features_'

# %%
print(x_train[0])
print(x_train_trans[0])
# Out:
# [2.76495139]
# [1.         2.76495139 7.64495617]

# %%
lr1=LinearRegression()
lr1.fit(x_train_trans,y_train)
# Out:
# LinearRegression()

# %%
y_pred1=lr1.predict(x_test_trans)
r2_score(y_test,y_pred1)
# Out:
# 0.9362142188809875

# %%
lr1.coef_
# Out:
# array([[0.        , 0.89760942, 1.01805966]])

# %%
lr1.intercept_
# Out:
# array([2.66871483])

# %%
x_new=np.linspace(-3,3,100).reshape(100,1)
x_new_poly=poly.transform(x_new)
y_new=lr1.predict(x_new_poly)

# %%
plt.plot(x_new,y_new,color="red",label="pridiction",linewidth=2)
plt.plot(x_train,y_train,"b.",label="training data")
plt.plot(x_test,y_test,"g.",label="test data")
plt.plot(x,y,'b.')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
