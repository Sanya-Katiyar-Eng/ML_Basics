# %% [markdown]
# Pie Chart

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
languages=["java","python","php","javascript","c#","c++"]
pop=[22.2,17.6,8.8,8,7.7,6.7]
plt.pie(pop,labels=languages,autopct="%1.1f%%",shadow=True,startangle=140,explode=[0.1,0,0,0,0,0])
# Out:
# ([<matplotlib.patches.Wedge at 0x183832c8050>,
# ...
#  [Text(-1.1518738600274299, -0.33643217828487987, 'java'),
#   Text(0.5025193836400076, -0.978506141557664, 'python'),
#   Text(1.0971674215735683, 0.07889010734945326, 'php'),
#   Text(0.7543405271097618, 0.8006062510121731, 'javascript'),
#   Text(0.06701861536005276, 1.0979565133443225, 'c#'),
#   Text(-0.5993298503773844, 0.9223902267731496, 'c++')],
#  [Text(-0.671926418349334, -0.19625210399951326, '31.3%'),
#   Text(0.27410148198545864, -0.5337306226678167, '24.8%'),
#   Text(0.5984549572219462, 0.043030967645156314, '12.4%'),
#   Text(0.41145846933259733, 0.43669431873391257, '11.3%'),
#   Text(0.03655560837821059, 0.5988853709150849, '10.8%'),
#   Text(-0.3269071911149369, 0.5031219418762634, '9.4%')])
